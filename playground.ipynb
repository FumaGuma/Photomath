# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from itertools import compress
import imageprocessing as ip
import solver

# %%
img_name = 'brojevi2.jpg'
ip.image_to_solution(img_name)
# Out:
# 109

# %%
img_name = 'brojevi2.jpg'
rect = ip.segment_image(img_name)
plt.imshow(ip.draw_rectangles(img_name,rect))

# %%
ip.process_image(img_name)
# Out:
# '43+4x18-(8+16)/4'

# %%
solver.solve('43+4x18-(8+16)/4')
# Out:
# 109

# %%
43+4*18-(8+16)/4
# Out:
# 109.0

# %%
plt.imshow(ip.cropped_dataset(img_name)[6])

# %%
cropp=ip.cropped_dataset(img_name)
ip.data_to_model(cropp)
# Out:
# '43+4x18-(8+16)/4'

# %%
img_name = 'brojevi5.jpg'
rect = ip.segment_image(img_name)
plt.imshow(ip.draw_rectangles(img_name,rect))

# %%
plt.imshow(ip.cropped_dataset(img_name)[8])

# %%
cropp=ip.cropped_dataset(img_name)
ip.data_to_model(cropp)
# Out:
# '79x(11+83)-4'

# %%
solver.solve('79x(11+83)-4')
# Out:
# 7422
