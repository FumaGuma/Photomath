# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from itertools import compress
import imageprocessing as ip
import solver

# %%
img_name = 'examples/test2.jpg'
rect = ip.segment_image(img_name)
plt.imshow(ip.draw_rectangles(img_name,rect))

# %%
ip.process_image(img_name)
# Out:
# '43+4x18-(8+16)/4'

# %%
solver.solve('43+4x18-(8+16)/4')
# Out:
# 109

# %%
43+4*18-(8+16)/4
# Out:
# 109.0

# %%
plt.imshow(ip.cropped_dataset(img_name)[6])

# %%
img_name = 'examples/test1.png'
rect = ip.segment_image(img_name)
plt.imshow(ip.draw_rectangles(img_name,rect))

# %%
ip.process_image(img_name)
# Out:
# '2-8x9/4'

# %%
solver.solve('2-8x9/4')
# Out:
# -16

# %%
plt.imshow(ip.cropped_dataset(img_name)[0])

# %%
img_name = 'examples/test6.jpg'
rect = ip.segment_image(img_name)
plt.imshow(ip.draw_rectangles(img_name,rect))

# %%
ip.process_image(img_name)
# Out:
# '4+9'

# %%
solver.solve('4+9')
# Out:
# 13

# %%
plt.imshow(ip.cropped_dataset(img_name)[0])

# %%
img_name = 'examples/test11.jpg'
rect = ip.segment_image(img_name)
plt.imshow(ip.draw_rectangles(img_name,rect))

# %%
ip.process_image(img_name)
# Out:
# '184+82'

# %%
solver.solve('184+82')
# Out:
# 266

# %%
plt.imshow(ip.cropped_dataset(img_name)[2])

# %%
img_name = 'examples/test7.jpg'
rect = ip.segment_image(img_name)
plt.imshow(ip.draw_rectangles(img_name,rect))

# %%
ip.process_image(img_name)
# Out:
# '4-2/3'

# %%
solver.solve('')
